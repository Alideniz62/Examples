# %%
import os
# save using vs code
SCALA_VERSION = '2.12'
SPARK_VERSION = '3.1.3'
# Download Kafka Jar file, this for readStream.format("kafka"), "kafka" is a driver
# kafka driver code is part of Maven Jar file
# https://mvnrepository.com/artifact/org.apache.spark/spark-sql-kafka-0-10_2.12/3.1.3
# pyspark-shell shall download the jar file behind..

# org.apache.spark:spark-sql-kafka-0-10_2.12:3.1.3'

os.environ['PYSPARK_SUBMIT_ARGS'] = f'--packages org.apache.spark:spark-sql-kafka-0-10_{SCALA_VERSION}:{SPARK_VERSION} pyspark-shell'

# %%
import sys
sys.stdout = open("/dev/stdout", "w")
print("Now my output shall be on terminal, not on my notebook")
# Out:
# Now my output shall be on terminal, not on my notebook
# :: loading settings :: url = jar:file:/opt/spark-3.1.3-bin-hadoop2.7/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)
#
# root
#  |-- value: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#
# root
#  |-- value: struct (nullable = true)
#  |    |-- symbol: string (nullable = true)
#  |    |-- price: double (nullable = true)
#  |    |-- volume: long (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#
# root
#  |-- symbol: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- volume: long (nullable = true)
#  |-- timestamp: long (nullable = true)
#
# root
#  |-- symbol: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- volume: long (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- traded_value: double (nullable = true)
#
# root
#  |-- symbol: string (nullable = true)
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- volume: long (nullable = true)
#  |-- traded_value: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- first: double (nullable = true)
#  |-- last: double (nullable = true)

# %%
import findspark
findspark.init()

# %%
import pyspark


from pyspark.sql import SparkSession
# spark groupBy has default setting for spark.sql.shuffle.partitions as 200
# we set to  4, should NOT be done in production 
spark = SparkSession.builder.master("local[1]")\
                            .config('spark.sql.shuffle.partitions', 4)\
                            .appName("SparkStreamingKafkaCandles").getOrCreate()
# Out:
# 22/03/31 20:20:33 WARN Utils: Your hostname, ubuntu-virtual-machine resolves to a loopback address: 127.0.1.1; using 192.168.80.128 instead (on interface ens33)
# 22/03/31 20:20:33 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /home/ubuntu/.ivy2/cache
# The jars for the packages stored in: /home/ubuntu/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-0a72c57d-3357-42da-974f-96b3480bf99a;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.1.3 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.1.3 in central
# 	found org.apache.kafka#kafka-clients;2.6.0 in central
# 	found com.github.luben#zstd-jni;1.4.8-1 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.2 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# :: resolution report :: resolve 626ms :: artifacts dl 11ms
# 	:: modules in use:
# 	com.github.luben#zstd-jni;1.4.8-1 from central in [default]
# 	org.apache.commons#commons-pool2;2.6.2 from central in [default]
# 	org.apache.kafka#kafka-clients;2.6.0 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.1.3 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.1.3 from central in [default]
# 	org.lz4#lz4-java;1.7.1 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.2 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   9   |   0   |   0   |   0   ||   9   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-0a72c57d-3357-42da-974f-96b3480bf99a
# 	confs: [default]
# 	0 artifacts copied, 9 already retrieved (0kB/11ms)
# 22/03/31 20:20:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# read from kafka, here spark is consumer for kafka topic called test
# spark streaming works as dataframe/sql
# group.id is consumer group id
# subcribe is kafka topic
# "kafka" driver is not available by default with spark, we need to download it, we did on cell 1
# GROUP ID SHOULD BE CHANGED FOR EVERY PERSON 
kafkaDf = spark.readStream.format("kafka")\
  .option("kafka.bootstrap.servers", "hadoop-vm:9092")\
  .option("subscribe", "stock-ticks")\
  .option("group.id", "stock-ticks-group2")\
  .load()

# %%
# key and value are binary type, we need to CAST To STRING type
kafkaDf.printSchema()
# timestampType values
# CreateTime:  Timestamp relates to message creation time as set by a Kafka client/producer
# LogAppendTime : Timestamp relates to the time a message was appended to a Kafka log.
# UnknownType

# %%
# Kafka value, key are in binary format
# we need to type cast to STRING, 
# we pick only value, timestamp as we need for 10 minute window
ticksDf = kafkaDf.selectExpr("CAST(value AS STRING)", "timestamp")
ticksDf.printSchema() # we get only value as string

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StructField, StructType, DoubleType, StringType, LongType, TimestampType

schema = StructType( [
    StructField("symbol", StringType(), True),
    StructField("price", DoubleType(), True),
    StructField("volume", LongType(), True),
    StructField("timestamp", LongType(),  True)
])

# %%
# we parse value which is JSON string to kafka struct, 
# this create a new column [replacing existing value which is string] with type
jsonDf = ticksDf.withColumn("value", F.from_json("value", schema))
jsonDf.printSchema()

# %%
# now extract all the sub fields symbol, price, volume, timestamp into data frame
# exisitng value, timestamp shall be removed. existing timestamp is value produced time, not a stock tick time
# value.timestamp that comes from producer is basically a event time
stockTickDf = jsonDf.select (F.col("value.*")) # extract all sub fields as schema
stockTickDf.printSchema()

# %%
stockTickDf = stockTickDf.withColumn("traded_value", F.col("price") * F.col("volume"))
stockTickDf.printSchema()

# %%
# we have data coming in stream, each record has timestamp
# we have milli seconds 1647283268253, the actual seconds Mon Mar 14 2022 14:41:08
# now we have to calculate 1 minute window, sum(volume) up to 1 minute
# after conversions, we take timestamp which is truncatd to minute instead of milli seconds, drop temp columns
stockTickDf = stockTickDf\
                .withColumn("timestampTemp", (F.col("timestamp") / 1000).cast("timestamp"))\
                .withColumn("trade_time", F.date_trunc("minute", F.col("timestampTemp")))\
                .drop("timestamp")\
                .drop("timestampTemp")\
                .withColumnRenamed("trade_time", "timestamp")

# %%
# now add delayed record processing with waterMark
stockTickDf1Min = stockTickDf\
                            .withWatermark("timestamp", "1 minutes")\
                            .groupBy("symbol", F.window("timestamp", "60 seconds"))\
                          .agg( F.sum("volume").alias("volume"),\
                                F.sum("traded_value").alias("traded_value"),\
                                F.max("price").alias("high"),\
                                F.min("price").alias("low"),\
                                F.first("price").alias("first"),\
                                F.last("price").alias("last")\
                              )
stockTickDf1Min.printSchema()

# echoOnconsole = stockTickDf1Min\
#                 .writeStream\
#                 .outputMode("update")\
#                 .format("console")\
#                 .option("truncate", False)\
#                 .start() # start the query. spark will subscribe for data

# write result to kafka
# we need to publish all the field together as value
# we take all columns, convert to json string
# publish json as value to kafka

stockTickDf1MinKafka = stockTickDf1Min\
                            .selectExpr("to_json(struct(*)) AS value")

stockTickDf1MinKafka\
            .writeStream\
             .format("kafka")\
            .outputMode("update")\
             .option("kafka.bootstrap.servers", "hadoop-vm:9092")\
            .option("topic", "candles-1min")\
            .option("checkpointLocation", "file:///tmp/spark3")\
            .start()
            
# use kafka console consumer to subscrbe candles-1min, command is given in 2 nd cell

# %%
def processBatchData(candleBatchDf, batch_id):
    print ("process batch called", batch_id, "writing ", candleBatchDf.count())
    # result = candleBatchDf.collect()
    # print(result)
    # candleBatchDf.show(2)
    # write to csv/json/parqeut/database /jdbc etc
    # window is nested column, has its children columns called start and end
    # start and end are part of nested window column
    # append mode will not delete existin data, instead append to existing table
    (
     candleBatchDf
        .select('*', F.col("window.*"))
        .withColumnRenamed("start", "start_time")
        .withColumnRenamed("end", "end_time")
        .drop("window")
        .write
        .mode("append")
        .format("jdbc")
        .option("url", "jdbc:mysql://localhost:3306/stockdb?autoReconnect=true&useSSL=false&allowPublicKeyRetrieval=true")
        .option("driver", "com.mysql.jdbc.Driver")
        .option("user", "team")
        .option("password", "Team1234!")
        .option("dbtable", "candle_1min")
         .save()
    )
    
stockTickDf1Min.writeStream.outputMode("append").foreachBatch(processBatchData).start()
# Out:
# 22/03/31 20:20:43 WARN StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-512a6117-bab8-4a91-9522-8b6eecf1f94b. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 22/03/31 20:20:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:48 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:48 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:48 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:48 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:20:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:20:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:01 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:01 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:01 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:01 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:16 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:16 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:19 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:19 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:25 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:25 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:28 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:28 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:31 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:31 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:34 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:34 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:40 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:40 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:41 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:41 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:44 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:44 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:44 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:44 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:47 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:47 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:49 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:49 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:52 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:52 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:56 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:56 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:59 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:59 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:21:59 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:21:59 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:08 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:08 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:08 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:08 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:22:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:22:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# ...
# 22/03/31 20:23:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:23:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:23:57 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:23:57 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:23:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:23:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:00 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:00 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:00 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:00 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:06 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:06 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:06 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:06 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:09 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:09 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:12 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:12 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:27 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:27 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0-2, groupId=spark-kafka-source-a9259039-318e-40d0-9e65-634b0d9bb3ea-246235410-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
# 22/03/31 20:24:30 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Connection to node -1 (hadoop-vm/192.168.11.218:9092) could not be established. Broker may not be available.
# 22/03/31 20:24:30 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0-1, groupId=spark-kafka-source-b376fbb7-cbe3-425e-9c2b-611dfec458a4-1876738793-driver-0] Bootstrap broker hadoop-vm:9092 (id: -1 rack: null) disconnected
